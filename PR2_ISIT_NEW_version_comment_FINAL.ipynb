# %%
# !pip install vk_api
# !pip install networkx
# !pip install matplotlib
# Out:
# Collecting vk_api
#   Downloading vk_api-11.9.9-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vk_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vk_api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vk_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vk_api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vk_api) (2024.8.30)
# Downloading vk_api-11.9.9-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: vk_api
# Successfully installed vk_api-11.9.9
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import vk_api
import time
import json

# Получение токена VK API
token = 'ТОКЕН'
vk_session = vk_api.VkApi(token=token)
vk = vk_session.get_api()

# Функция для получения списка друзей пользователя с ограничением времени на запрос и количеством друзей
def get_friends(user_id):
    try:
        start_time = time.time()
        friends = vk.friends.get(user_id=user_id, fields='nickname', count=100)
        if time.time() - start_time > 3:
            raise TimeoutError("Request took longer than 3 seconds")
        return friends['items']
    except (vk_api.exceptions.VkApiError, TimeoutError) as e:
        print(f"Error getting friends for user {user_id}: {e}")
        return []

# Список ID целевых пользователей
target_user_ids = [172350665, 229180632, 145195585, 193887357, 386272361, 204720239, 162225997, 860446539,
                   472133870, 195614586, 825545292, 750743366, 637593527, 299106540, 164679738, 101098087,
                                      239666833, 342040017, 205762499, 165171730, 270780454, 155290829, 151413977, 62269831,
                                                         253407490, 192574298, 144399122, 419376445, 508644412, 396854328]

# Список для хранения всех пользователей и их друзей
friendships = []

# Получение информации о друзьях для каждого пользователя и проверка связей между друзьями
for user_id in target_user_ids:
    friends = get_friends(user_id)
    user_friend_ids = [friend['id'] for friend in friends]

    # Добавляем связь между пользователем и его друзьями
    for friend_id in user_friend_ids:
        friendships.append((user_id, friend_id))

        # Получаем друзей каждого друга
        friend_friends = get_friends(friend_id)
        friend_friend_ids = [f['id'] for f in friend_friends]

        # Проверка дружбы между друзьями
        for i, f1_id in enumerate(friend_friend_ids):
            for f2_id in friend_friend_ids[i + 1:]:
                # Проверка, есть ли связь между двумя друзьями
                if f2_id in user_friend_ids and (f1_id, f2_id) not in friendships and (f2_id, f1_id) not in friendships:
                    friendships.append((f1_id, f2_id))

# Список связей в файл JSON
with open('friends_data.json', 'w') as f:
    json.dump(friendships, f)

print("Данные друзей успешно сохранены в 'friends_data.json'")
# Out:
# Error getting friends for user 51911288: [30] This profile is private
# Error getting friends for user 58410032: [30] This profile is private
# Error getting friends for user 59538294: [30] This profile is private
# Error getting friends for user 73989913: [30] This profile is private
# Error getting friends for user 116543501: [30] This profile is private
# Error getting friends for user 143253371: [30] This profile is private
# Error getting friends for user 143579152: [30] This profile is private
# Error getting friends for user 156241172: [30] This profile is private
# Error getting friends for user 157841304: [30] This profile is private
# Error getting friends for user 159813255: [30] This profile is private
# Error getting friends for user 160096443: [30] This profile is private
# Error getting friends for user 163549843: [30] This profile is private
# Error getting friends for user 178937702: [30] This profile is private
# Error getting friends for user 182278035: [30] This profile is private
# Error getting friends for user 184684350: [30] This profile is private
# Error getting friends for user 201167687: [30] This profile is private
# Error getting friends for user 207005764: [30] This profile is private
# Error getting friends for user 212365718: [30] This profile is private
# Error getting friends for user 219800699: [30] This profile is private
# Error getting friends for user 223503550: [30] This profile is private
# Error getting friends for user 236434667: [30] This profile is private
# Error getting friends for user 245823210: [30] This profile is private
# Error getting friends for user 246480474: [30] This profile is private
# Error getting friends for user 258216127: [30] This profile is private
# Error getting friends for user 286878494: [30] This profile is private
# Error getting friends for user 309233869: [30] This profile is private
# Error getting friends for user 316638070: [30] This profile is private
# Error getting friends for user 2047488: [30] This profile is private
# Error getting friends for user 4839454: [30] This profile is private
# Error getting friends for user 18501313: [30] This profile is private
# Error getting friends for user 73708828: [30] This profile is private
# Error getting friends for user 146920700: [18] User was deleted or banned
# Error getting friends for user 170893789: [30] This profile is private
# Error getting friends for user 182278035: [30] This profile is private
# Error getting friends for user 185376012: [30] This profile is private
# Error getting friends for user 212402091: [30] This profile is private
# Error getting friends for user 223200017: [30] This profile is private
# Error getting friends for user 235367802: [30] This profile is private
# Error getting friends for user 268815963: [30] This profile is private
# Error getting friends for user 306356294: [30] This profile is private
# Error getting friends for user 381528565: [30] This profile is private
# Error getting friends for user 11633443: [30] This profile is private
# Error getting friends for user 20653048: [30] This profile is private
# Error getting friends for user 48339656: [30] This profile is private
# Error getting friends for user 55462384: [30] This profile is private
# Error getting friends for user 58079368: [30] This profile is private
# Error getting friends for user 60461705: [30] This profile is private
# Error getting friends for user 67020920: [30] This profile is private
# Error getting friends for user 82124364: [30] This profile is private
# Error getting friends for user 96633409: [30] This profile is private
# Error getting friends for user 119623977: [30] This profile is private
# Error getting friends for user 135204355: [30] This profile is private
# Error getting friends for user 152779293: [30] This profile is private
# Error getting friends for user 161027685: [30] This profile is private
# Error getting friends for user 161665914: [30] This profile is private
# Error getting friends for user 168787027: [18] User was deleted or banned
# Error getting friends for user 175931427: [30] This profile is private
# Error getting friends for user 178198024: [30] This profile is private
# Error getting friends for user 196302283: [30] This profile is private
# Error getting friends for user 198674206: [30] This profile is private
# Error getting friends for user 210137004: [30] This profile is private
# Error getting friends for user 214791458: [30] This profile is private
# Error getting friends for user 223153780: [30] This profile is private
# Error getting friends for user 10642658: [18] User was deleted or banned
# Error getting friends for user 14584184: [30] This profile is private
# Error getting friends for user 18214144: [30] This profile is private
# Error getting friends for user 28960504: [30] This profile is private
# Error getting friends for user 65869602: [30] This profile is private
# Error getting friends for user 69515576: [30] This profile is private
# Error getting friends for user 72880369: [30] This profile is private
# Error getting friends for user 98539110: [30] This profile is private
# Error getting friends for user 143379961: [30] This profile is private
# Error getting friends for user 143591567: [30] This profile is private
# Error getting friends for user 143616099: [30] This profile is private
# Error getting friends for user 151413977: [30] This profile is private
# Error getting friends for user 165874729: [30] This profile is private
# Error getting friends for user 170781952: [30] This profile is private
# Error getting friends for user 173063624: [30] This profile is private
# Error getting friends for user 178692802: [30] This profile is private
# Error getting friends for user 180740956: [30] This profile is private
# Error getting friends for user 180892192: [30] This profile is private
# Error getting friends for user 182278035: [30] This profile is private
# Error getting friends for user 182831230: [30] This profile is private
# Error getting friends for user 183967179: [30] This profile is private
# Error getting friends for user 189957161: [30] This profile is private
# Error getting friends for user 190320878: [30] This profile is private
# Error getting friends for user 201167687: [30] This profile is private
# Error getting friends for user 205236096: [30] This profile is private
# Error getting friends for user 207410801: [30] This profile is private
# Error getting friends for user 213520652: [30] This profile is private
# Error getting friends for user 2674013: [18] User was deleted or banned
# Error getting friends for user 51722657: [30] This profile is private
# Error getting friends for user 140773308: [30] This profile is private
# Error getting friends for user 145149916: [30] This profile is private
# Error getting friends for user 166498661: [30] This profile is private
# Error getting friends for user 205072047: [30] This profile is private
# Error getting friends for user 207702608: [30] This profile is private
# Error getting friends for user 226218425: [30] This profile is private
# Error getting friends for user 226815262: [30] This profile is private
# Error getting friends for user 229798294: [30] This profile is private
# Error getting friends for user 231441484: [30] This profile is private
# Error getting friends for user 255842179: [30] This profile is private
# Error getting friends for user 261263165: [30] This profile is private
# Error getting friends for user 297387665: [30] This profile is private
# Error getting friends for user 312645934: [30] This profile is private
# Error getting friends for user 389513964: [30] This profile is private
# Error getting friends for user 444761995: [30] This profile is private
# Error getting friends for user 493968946: [30] This profile is private
# Error getting friends for user 509938807: [30] This profile is private
# Error getting friends for user 4566728: [18] User was deleted or banned
# Error getting friends for user 10382696: [30] This profile is private
# Error getting friends for user 11022265: [30] This profile is private
# Error getting friends for user 25113311: [18] User was deleted or banned
# Error getting friends for user 26892759: [30] This profile is private
# Error getting friends for user 33825296: [30] This profile is private
# Error getting friends for user 42234482: [30] This profile is private
# Error getting friends for user 52566073: [30] This profile is private
# Error getting friends for user 53142595: [30] This profile is private
# Error getting friends for user 54128510: [30] This profile is private
# Error getting friends for user 90930224: [30] This profile is private
# Error getting friends for user 111080723: [30] This profile is private
# Error getting friends for user 131717599: [30] This profile is private
# Error getting friends for user 147094129: [30] This profile is private
# Error getting friends for user 150493535: [30] This profile is private
# Error getting friends for user 151197016: [30] This profile is private
# Error getting friends for user 162037931: [30] This profile is private
# Error getting friends for user 163016190: [30] This profile is private
# Error getting friends for user 167647131: [30] This profile is private
# Error getting friends for user 169021767: [30] This profile is private
# Error getting friends for user 169684701: [30] This profile is private
# Error getting friends for user 173049922: [30] This profile is private
# Error getting friends for user 181420436: [30] This profile is private
# Error getting friends for user 182059061: [18] User was deleted or banned
# Error getting friends for user 183738542: [30] This profile is private
# Error getting friends for user 62504942: [30] This profile is private
# Error getting friends for user 65274323: [30] This profile is private
# Error getting friends for user 93578401: [30] This profile is private
# Error getting friends for user 101794720: [30] This profile is private
# Error getting friends for user 133238913: [30] This profile is private
# Error getting friends for user 165041497: [30] This profile is private
# Error getting friends for user 167138457: [30] This profile is private
# Error getting friends for user 174403750: [30] This profile is private
# Error getting friends for user 191478647: [30] This profile is private
# Error getting friends for user 194813265: [30] This profile is private
# Error getting friends for user 196845383: [30] This profile is private
# Error getting friends for user 196870128: [30] This profile is private
# Error getting friends for user 202291584: [30] This profile is private
# Error getting friends for user 214701397: [30] This profile is private
# Error getting friends for user 228701702: [30] This profile is private
# Error getting friends for user 318447613: [30] This profile is private
# Error getting friends for user 345547828: [30] This profile is private
# Error getting friends for user 439111407: [30] This profile is private
# Error getting friends for user 442490895: [30] This profile is private
# Error getting friends for user 445920621: [30] This profile is private
# Error getting friends for user 448813072: [18] User was deleted or banned
# Error getting friends for user 461814307: [30] This profile is private
# Error getting friends for user 471721691: [30] This profile is private
# Error getting friends for user 523418365: [30] This profile is private
# Error getting friends for user 540803533: [30] This profile is private
# Error getting friends for user 625056751: [30] This profile is private
# Error getting friends for user 635219072: [30] This profile is private
# Error getting friends for user 647714950: [30] This profile is private
# Error getting friends for user 688646721: [30] This profile is private
# Error getting friends for user 704562314: [30] This profile is private
# Error getting friends for user 780933474: [30] This profile is private
# Error getting friends for user 167894685: [30] This profile is private
# Error getting friends for user 168634762: [18] User was deleted or banned
# Error getting friends for user 171742671: [30] This profile is private
# Error getting friends for user 173226999: [30] This profile is private
# Error getting friends for user 182798626: [30] This profile is private
# Error getting friends for user 195437425: [30] This profile is private
# Error getting friends for user 203072721: [30] This profile is private
# Error getting friends for user 212605409: [30] This profile is private
# Error getting friends for user 224073229: [30] This profile is private
# Error getting friends for user 231197765: [30] This profile is private
# Error getting friends for user 240645052: [30] This profile is private
# Error getting friends for user 243955509: [30] This profile is private
# Error getting friends for user 270797462: [30] This profile is private
# Error getting friends for user 275399731: [30] This profile is private
# Error getting friends for user 277554569: [30] This profile is private
# Error getting friends for user 278490623: [30] This profile is private
# Error getting friends for user 280127404: [30] This profile is private
# Error getting friends for user 289860147: [30] This profile is private
# Error getting friends for user 297070664: [30] This profile is private
# Error getting friends for user 308918123: [30] This profile is private
# Error getting friends for user 314582636: [30] This profile is private
# Error getting friends for user 2060370: [30] This profile is private
# Error getting friends for user 35889796: [30] This profile is private
# Error getting friends for user 75086997: [18] User was deleted or banned
# Error getting friends for user 84074672: [30] This profile is private
# Error getting friends for user 168025021: [30] This profile is private
# Error getting friends for user 183473690: [30] This profile is private
# Error getting friends for user 189957161: [30] This profile is private
# Error getting friends for user 190939140: [30] This profile is private
# Error getting friends for user 196136311: [30] This profile is private
# Error getting friends for user 206449177: [30] This profile is private
# Error getting friends for user 214316227: [30] This profile is private
# Error getting friends for user 221475204: [30] This profile is private
# Error getting friends for user 242665001: [30] This profile is private
# Error getting friends for user 243955509: [30] This profile is private
# Error getting friends for user 271126272: [30] This profile is private
# Error getting friends for user 171065531: [30] This profile is private
# Error getting friends for user 811711369: [30] This profile is private
# Error getting friends for user 825332102: [30] This profile is private
# Error getting friends for user 32267442: [30] This profile is private
# Error getting friends for user 183489395: [30] This profile is private
# Error getting friends for user 305162297: [30] This profile is private
# Error getting friends for user 465507817: [30] This profile is private
# Error getting friends for user 607780988: [30] This profile is private
# Error getting friends for user 615005241: [30] This profile is private
# Error getting friends for user 622831323: [30] This profile is private
# Error getting friends for user 62936673: [30] This profile is private
# Error getting friends for user 95835995: [30] This profile is private
# Error getting friends for user 165343101: [30] This profile is private
# Error getting friends for user 170125467: [30] This profile is private
# Error getting friends for user 210146223: [30] This profile is private
# Error getting friends for user 215467260: [30] This profile is private
# Error getting friends for user 232101776: [30] This profile is private
# Error getting friends for user 238555507: [30] This profile is private
# Error getting friends for user 283216101: [30] This profile is private
# Error getting friends for user 325680932: [30] This profile is private
# Error getting friends for user 337036980: [30] This profile is private
# Error getting friends for user 356140239: [30] This profile is private
# Error getting friends for user 366315139: [30] This profile is private
# Error getting friends for user 381986202: [30] This profile is private
# Error getting friends for user 403299853: [30] This profile is private
# Error getting friends for user 410546727: [30] This profile is private
# Error getting friends for user 459630798: [30] This profile is private
# Error getting friends for user 463124010: [18] User was deleted or banned
# Error getting friends for user 485449302: [30] This profile is private
# Error getting friends for user 517099875: [30] This profile is private
# Error getting friends for user 562700396: [30] This profile is private
# Error getting friends for user 73119102: [30] This profile is private
# Error getting friends for user 134904215: [30] This profile is private
# Error getting friends for user 173063624: [30] This profile is private
# Error getting friends for user 186959593: [30] This profile is private
# Error getting friends for user 189068322: [30] This profile is private
# Error getting friends for user 189957161: [30] This profile is private
# Error getting friends for user 196492304: [30] This profile is private
# Error getting friends for user 213624043: [30] This profile is private
# Error getting friends for user 243282350: [30] This profile is private
# Error getting friends for user 244249300: [30] This profile is private
# Error getting friends for user 264207953: [30] This profile is private
# Error getting friends for user 267588871: [30] This profile is private
# Error getting friends for user 270839097: [30] This profile is private
# Error getting friends for user 271081038: [30] This profile is private
# Error getting friends for user 278178249: [18] User was deleted or banned
# Error getting friends for user 286145605: [30] This profile is private
# Error getting friends for user 306158066: [30] This profile is private
# Error getting friends for user 308306832: [30] This profile is private
# Error getting friends for user 311001565: [30] This profile is private
# Error getting friends for user 313374638: [30] This profile is private
# Error getting friends for user 321819438: [30] This profile is private
# Error getting friends for user 322092767: [30] This profile is private
# Error getting friends for user 354088711: [30] This profile is private
# Error getting friends for user 381528565: [30] This profile is private
# Error getting friends for user 450149928: [30] This profile is private
# Error getting friends for user 458374632: [30] This profile is private
# Error getting friends for user 462075624: [30] This profile is private
# Error getting friends for user 480280875: [30] This profile is private
# Error getting friends for user 493832970: [30] This profile is private
# Error getting friends for user 498695917: [18] User was deleted or banned
# Error getting friends for user 514547503: [30] This profile is private
# Error getting friends for user 517607473: [30] This profile is private
# Error getting friends for user 4114739: [30] This profile is private
# Error getting friends for user 32167094: [30] This profile is private
# Error getting friends for user 59141600: [30] This profile is private
# Error getting friends for user 120205805: [30] This profile is private
# Error getting friends for user 121162652: [30] This profile is private
# Error getting friends for user 138314382: [30] This profile is private
# Error getting friends for user 144824929: [30] This profile is private
# Error getting friends for user 152902407: [30] This profile is private
# Error getting friends for user 153130225: [30] This profile is private
# Error getting friends for user 156667230: [30] This profile is private
# Error getting friends for user 156896839: [30] This profile is private
# Error getting friends for user 161887754: [30] This profile is private
# Error getting friends for user 161890264: [30] This profile is private
# Error getting friends for user 163058396: [30] This profile is private
# Error getting friends for user 165119515: [30] This profile is private
# Error getting friends for user 166506281: [18] User was deleted or banned
# Error getting friends for user 167421463: [30] This profile is private
# Error getting friends for user 168912316: [30] This profile is private
# Error getting friends for user 170522636: [30] This profile is private
# Error getting friends for user 172712423: [30] This profile is private
# Error getting friends for user 173063624: [30] This profile is private
# Error getting friends for user 174856476: [30] This profile is private
# Error getting friends for user 176444560: [30] This profile is private
# Error getting friends for user 177043348: [30] This profile is private
# Error getting friends for user 195653418: [30] This profile is private
# Error getting friends for user 19226188: [30] This profile is private
# Error getting friends for user 48412454: [30] This profile is private
# Error getting friends for user 59925090: [30] This profile is private
# Error getting friends for user 93685653: [30] This profile is private
# Error getting friends for user 95487210: [30] This profile is private
# Error getting friends for user 98539110: [30] This profile is private
# Error getting friends for user 124026422: [18] User was deleted or banned
# Error getting friends for user 143650139: [30] This profile is private
# Error getting friends for user 150669142: [30] This profile is private
# Error getting friends for user 151413977: [30] This profile is private
# Error getting friends for user 170203371: [30] This profile is private
# Error getting friends for user 175558302: [30] This profile is private
# Error getting friends for user 182831230: [30] This profile is private
# Error getting friends for user 183489395: [30] This profile is private
# Error getting friends for user 183967179: [30] This profile is private
# Error getting friends for user 184860057: [30] This profile is private
# Error getting friends for user 187228321: [30] This profile is private
# Error getting friends for user 188460486: [30] This profile is private
# Error getting friends for user 195121266: [30] This profile is private
# Error getting friends for user 201488665: [30] This profile is private
# Error getting friends for user 202448351: [30] This profile is private
# Error getting friends for user 202619479: [30] This profile is private
# Error getting friends for user 213954978: [30] This profile is private
# Error getting friends for user 20824105: [30] This profile is private
# Error getting friends for user 42220567: [30] This profile is private
# Error getting friends for user 59181636: [30] This profile is private
# Error getting friends for user 127131839: [30] This profile is private
# Error getting friends for user 132098474: [30] This profile is private
# Error getting friends for user 138025609: [30] This profile is private
# Error getting friends for user 173063624: [30] This profile is private
# Error getting friends for user 185131011: [30] This profile is private
# Error getting friends for user 189957161: [30] This profile is private
# Error getting friends for user 190145523: [30] This profile is private
# Error getting friends for user 200834151: [30] This profile is private
# Error getting friends for user 214382424: [30] This profile is private
# Error getting friends for user 302640310: [30] This profile is private
# Error getting friends for user 333355903: [30] This profile is private
# Error getting friends for user 344347155: [30] This profile is private
# Error getting friends for user 463124010: [18] User was deleted or banned
# Error getting friends for user 551180548: [30] This profile is private
# Error getting friends for user 602242162: [30] This profile is private
# Error getting friends for user 614395764: [18] User was deleted or banned
# Error getting friends for user 3078471: [30] This profile is private
# Error getting friends for user 6753897: [30] This profile is private
# Error getting friends for user 7732622: [30] This profile is private
# Error getting friends for user 11345032: [30] This profile is private
# Error getting friends for user 15890627: [30] This profile is private
# Error getting friends for user 18493057: [30] This profile is private
# Error getting friends for user 50654552: [30] This profile is private
# Error getting friends for user 84198702: [30] This profile is private
# Error getting friends for user 90543476: [30] This profile is private
# Error getting friends for user 90793333: [30] This profile is private
# Error getting friends for user 107700058: [30] This profile is private
# Error getting friends for user 123027302: [30] This profile is private
# Error getting friends for user 138049889: [30] This profile is private
# Error getting friends for user 138374302: [30] This profile is private
# Error getting friends for user 144636586: [30] This profile is private
# Error getting friends for user 147094129: [30] This profile is private
# Error getting friends for user 150398505: [30] This profile is private
# Error getting friends for user 157426800: [30] This profile is private
# Error getting friends for user 165391589: [30] This profile is private
# Error getting friends for user 173049922: [30] This profile is private
# Error getting friends for user 178713337: [30] This profile is private
# Error getting friends for user 179768043: [30] This profile is private
# Error getting friends for user 196188236: [30] This profile is private
# Error getting friends for user 204374726: [30] This profile is private
# Error getting friends for user 204385769: [30] This profile is private
# Error getting friends for user 1703941: [30] This profile is private
# Error getting friends for user 6179242: [30] This profile is private
# Error getting friends for user 15105337: [30] This profile is private
# Error getting friends for user 18077095: [30] This profile is private
# Error getting friends for user 18268660: [30] This profile is private
# Error getting friends for user 52532954: [30] This profile is private
# Error getting friends for user 55923917: [30] This profile is private
# Error getting friends for user 71156120: [30] This profile is private
# Error getting friends for user 72945648: [30] This profile is private
# Error getting friends for user 80273154: [30] This profile is private
# Error getting friends for user 83141006: [30] This profile is private
# Error getting friends for user 92811371: [30] This profile is private
# Error getting friends for user 95976754: [30] This profile is private
# Error getting friends for user 97213823: [30] This profile is private
# Error getting friends for user 112637978: [30] This profile is private
# Error getting friends for user 117680136: [30] This profile is private
# Error getting friends for user 123510429: [30] This profile is private
# Error getting friends for user 126095095: [30] This profile is private
# Error getting friends for user 137775864: [30] This profile is private
# Error getting friends for user 140460421: [30] This profile is private
# Error getting friends for user 144399122: [30] This profile is private
# Error getting friends for user 146043385: [30] This profile is private
# Error getting friends for user 146503171: [30] This profile is private
# Error getting friends for user 151413977: [30] This profile is private
# Error getting friends for user 152184806: [30] This profile is private
# Error getting friends for user 152743076: [30] This profile is private
# Error getting friends for user 5828994: [30] This profile is private
# Error getting friends for user 37048701: [30] This profile is private
# Error getting friends for user 44647885: [18] User was deleted or banned
# Error getting friends for user 55899990: [18] User was deleted or banned
# Error getting friends for user 63971609: [18] User was deleted or banned
# Error getting friends for user 69957899: [30] This profile is private
# Error getting friends for user 89112870: [30] This profile is private
# Error getting friends for user 93506683: [30] This profile is private
# Error getting friends for user 120205805: [30] This profile is private
# Error getting friends for user 123069417: [30] This profile is private
# Error getting friends for user 125436313: [18] User was deleted or banned
# Error getting friends for user 141956251: [30] This profile is private
# Error getting friends for user 142194767: [18] User was deleted or banned
# Error getting friends for user 147685771: [18] User was deleted or banned
# Error getting friends for user 149050564: [30] This profile is private
# Error getting friends for user 150551552: [18] User was deleted or banned
# Error getting friends for user 152293816: [18] User was deleted or banned
# Error getting friends for user 152527191: [30] This profile is private
# Error getting friends for user 154126151: [30] This profile is private
# Error getting friends for user 155770915: [30] This profile is private
# Error getting friends for user 156566199: [30] This profile is private
# Error getting friends for user 157677713: [18] User was deleted or banned
# Error getting friends for user 159791421: [18] User was deleted or banned
# Error getting friends for user 161082843: [30] This profile is private
# Error getting friends for user 165159154: [18] User was deleted or banned
# Error getting friends for user 166197558: [18] User was deleted or banned
# Error getting friends for user 171654160: [30] This profile is private
# Error getting friends for user 172573887: [18] User was deleted or banned
# Error getting friends for user 173859723: [30] This profile is private
# Error getting friends for user 185680345: [18] User was deleted or banned
# Error getting friends for user 186301908: [30] This profile is private
# Error getting friends for user 186545130: [18] User was deleted or banned
# Error getting friends for user 189790907: [18] User was deleted or banned
# Error getting friends for user 199767103: [30] This profile is private
# Error getting friends for user 200123389: [30] This profile is private
# Error getting friends for user 203448096: [30] This profile is private
# Error getting friends for user 208959003: [18] User was deleted or banned
# Error getting friends for user 212898466: [18] User was deleted or banned
# Error getting friends for user 217047763: [30] This profile is private
# Error getting friends for user 151413977: [30] This profile is private
# Error getting friends for user 7178722: [30] This profile is private
# Error getting friends for user 13286775: [30] This profile is private
# Error getting friends for user 102810433: [30] This profile is private
# Error getting friends for user 136843089: [30] This profile is private
# Error getting friends for user 139388262: [30] This profile is private
# Error getting friends for user 144698793: [30] This profile is private
# Error getting friends for user 147278383: [30] This profile is private
# Error getting friends for user 156842289: [30] This profile is private
# Error getting friends for user 165050896: [30] This profile is private
# Error getting friends for user 195168747: [18] User was deleted or banned
# Error getting friends for user 224759520: [30] This profile is private
# Error getting friends for user 229881622: [30] This profile is private
# Error getting friends for user 248312262: [30] This profile is private
# Error getting friends for user 265247487: [30] This profile is private
# Error getting friends for user 266630330: [30] This profile is private
# Error getting friends for user 284212489: [30] This profile is private
# Error getting friends for user 329105931: [30] This profile is private
# Error getting friends for user 417156582: [30] This profile is private
# Error getting friends for user 463124010: [18] User was deleted or banned
# Error getting friends for user 516528330: [30] This profile is private
# Error getting friends for user 680048039: [30] This profile is private
# Error getting friends for user 2279921: [30] This profile is private
# Error getting friends for user 11772139: [30] This profile is private
# Error getting friends for user 47319558: [30] This profile is private
# Error getting friends for user 47953047: [30] This profile is private
# Error getting friends for user 63627434: [30] This profile is private
# Error getting friends for user 85068423: [18] User was deleted or banned
# Error getting friends for user 86963584: [30] This profile is private
# Error getting friends for user 101007942: [30] This profile is private
# Error getting friends for user 105113766: [18] User was deleted or banned
# Error getting friends for user 134074908: [30] This profile is private
# Error getting friends for user 156328076: [30] This profile is private
# Error getting friends for user 160520654: [30] This profile is private
# Error getting friends for user 167545894: [30] This profile is private
# Error getting friends for user 173063624: [30] This profile is private
# Error getting friends for user 180770069: [30] This profile is private
# Error getting friends for user 186648059: [30] This profile is private
# Error getting friends for user 188978380: [30] This profile is private
# Error getting friends for user 189957161: [30] This profile is private
# Error getting friends for user 191715640: [30] This profile is private
# Error getting friends for user 1795692: [30] This profile is private
# Error getting friends for user 7370230: [30] This profile is private
# Error getting friends for user 61121355: [30] This profile is private
# Error getting friends for user 76902857: [30] This profile is private
# Error getting friends for user 111480708: [18] User was deleted or banned
# Error getting friends for user 118484570: [30] This profile is private
# Error getting friends for user 124558881: [30] This profile is private
# Error getting friends for user 124934580: [30] This profile is private
# Error getting friends for user 139549259: [30] This profile is private
# Error getting friends for user 145725348: [30] This profile is private
# Error getting friends for user 151403748: [30] This profile is private
# Error getting friends for user 152252695: [30] This profile is private
# Error getting friends for user 159825703: [18] User was deleted or banned
# Error getting friends for user 162755053: [30] This profile is private
# Error getting friends for user 166884622: [18] User was deleted or banned
# Error getting friends for user 173543128: [18] User was deleted or banned
# Error getting friends for user 176931477: [30] This profile is private
# Error getting friends for user 181728986: [30] This profile is private
# Error getting friends for user 190893375: [30] This profile is private
# Error getting friends for user 193344311: [30] This profile is private
# Error getting friends for user 198537718: [30] This profile is private
# Error getting friends for user 144399122: [30] This profile is private
# Error getting friends for user 54128510: [30] This profile is private
# Error getting friends for user 83562325: [30] This profile is private
# Error getting friends for user 97656209: [30] This profile is private
# Error getting friends for user 122800757: [30] This profile is private
# Error getting friends for user 147320760: [30] This profile is private
# Error getting friends for user 152993062: [30] This profile is private
# Error getting friends for user 163420606: [30] This profile is private
# Error getting friends for user 164101771: [30] This profile is private
# Error getting friends for user 174913533: [30] This profile is private
# Error getting friends for user 197468925: [30] This profile is private
# Error getting friends for user 206098817: [30] This profile is private
# Error getting friends for user 213460666: [30] This profile is private
# Error getting friends for user 230986158: [30] This profile is private
# Error getting friends for user 233453149: [30] This profile is private
# Error getting friends for user 233811236: [30] This profile is private
# Error getting friends for user 272095832: [30] This profile is private
# Error getting friends for user 277428209: [30] This profile is private
# Error getting friends for user 293820014: [30] This profile is private
# Error getting friends for user 331849215: [30] This profile is private
# Error getting friends for user 52451724: [30] This profile is private
# Error getting friends for user 201167687: [30] This profile is private
# Error getting friends for user 241235607: [30] This profile is private
# Error getting friends for user 276695760: [30] This profile is private
# Error getting friends for user 304081097: [30] This profile is private
# Error getting friends for user 426669949: [30] This profile is private
# Error getting friends for user 431969543: [30] This profile is private
# Error getting friends for user 467139007: [30] This profile is private
# Error getting friends for user 1103698: [30] This profile is private
# Error getting friends for user 4097831: [30] This profile is private
# Error getting friends for user 8735317: [30] This profile is private
# Error getting friends for user 13723219: [30] This profile is private
# Error getting friends for user 29097926: [30] This profile is private
# Error getting friends for user 55066129: [30] This profile is private
# Error getting friends for user 80295892: [30] This profile is private
# Error getting friends for user 98539110: [30] This profile is private
# Error getting friends for user 135346458: [30] This profile is private
# Error getting friends for user 141410078: [18] User was deleted or banned
# Error getting friends for user 151413977: [30] This profile is private
# Error getting friends for user 174257084: [30] This profile is private
# Error getting friends for user 189371087: [30] This profile is private
# Error getting friends for user 227796341: [30] This profile is private
# Error getting friends for user 322924173: [30] This profile is private
# Error getting friends for user 345322035: [30] This profile is private
# Error getting friends for user 426228839: [30] This profile is private
# Error getting friends for user 471130764: [30] This profile is private
# Error getting friends for user 546098646: [30] This profile is private
# Данные друзей успешно сохранены в 'friends_data.json'

# %%
import networkx as nx
import matplotlib.pyplot as plt
import json

# Загрузка данных из файла
with open('friends_data.json', 'r') as f:
    friendships = json.load(f)

# Построение графа
G = nx.Graph()
G.add_edges_from(friendships)


nodes_to_remove = [node for node in G.nodes() if G.degree(node) < 2]
G.remove_nodes_from(nodes_to_remove)


num_edges = G.number_of_edges()
num_nodes = G.number_of_nodes()
print(f"Количество рёбер: {num_edges}")
print(f"Количество вершин: {num_nodes}")

betweenness = nx.betweenness_centrality(G)
closeness = nx.closeness_centrality(G)
eigenvector = nx.eigenvector_centrality(G)


pos = nx.spring_layout(G, seed=42, k=0.15)

target_user_ids = [172350665, 229180632, 145195585, 193887357, 386272361, 204720239, 162225997, 860446539,
                   472133870, 195614586, 825545292, 750743366, 637593527, 299106540, 164679738, 101098087,
                                      239666833, 342040017, 205762499, 165171730, 270780454, 155290829, 151413977, 62269831,
                                                         253407490, 192574298, 144399122, 419376445, 508644412, 396854328]
node_colors = ['blue' if node in target_user_ids else 'white' for node in G.nodes()]

plt.figure(figsize=(20, 20))
nx.draw_networkx_edges(G, pos, edge_color='#888', width=0.5)
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=100, edgecolors='black')

plt.title('Граф друзей (выделены целевые пользователи)')
plt.axis('off')
plt.show()
# Out:
# Количество рёбер: 290103
# Количество вершин: 43750

# %%
import vk_api
import json
import time
import networkx as nx

# Получение токена VK API
token = 'ТОКЕН'
vk_session = vk_api.VkApi(token=token)
vk = vk_session.get_api()

# Список ID целевых пользователей
target_user_ids = [172350665, 229180632, 145195585, 193887357, 386272361, 204720239, 162225997, 860446539,
                   472133870, 195614586, 825545292, 750743366, 637593527, 299106540, 164679738, 101098087,
                                      239666833, 342040017, 205762499, 165171730, 270780454, 155290829, 151413977, 62269831,
                                                         253407490, 192574298, 144399122, 419376445, 508644412, 396854328]

# Получение имен пользователей
user_names = {}
for user_id in target_user_ids:
    try:
        user_info = vk.users.get(user_ids=user_id)[0]
        full_name = f"{user_info['first_name']} {user_info['last_name']}"
        user_names[user_id] = full_name
        time.sleep(0.34)
    except vk_api.exceptions.VkApiError as e:
        print(f"Error fetching user info for {user_id}: {e}")


with open('user_names.json', 'w') as f:
    json.dump(user_names, f)

print("Имена пользователей успешно сохранены в 'user_names.json'")



# Загрузка данных
with open('friends_data.json', 'r') as f:
    friendships = json.load(f)

with open('user_names.json', 'r') as f:
    user_names = json.load(f)


target_user_ids = set(int(user_id) for user_id in user_names.keys())

# Инициализация графа
G = nx.Graph()
G.add_edges_from(friendships)


nodes_to_remove = [node for node in G.nodes() if G.degree(node) < 2]
G.remove_nodes_from(nodes_to_remove)

# Оценка центральности
betweenness = nx.betweenness_centrality(G)
closeness = nx.closeness_centrality(G)
eigenvector = nx.eigenvector_centrality(G)

# Сортировка пользователей
def sorted_centrality(centrality_dict):
    return sorted(
        ((user, centrality_dict[user]) for user in target_user_ids if user in centrality_dict),
        key=lambda x: x[1],
        reverse=True
    )

# Вывод оценки центральностей (по убыванию)
print("\nЦентральность по посредничеству (betweenness):")
for user, centrality in sorted_centrality(betweenness):
    name = user_names.get(str(user), f"User ID: {user}")
    print(f"{name}, Betweenness: {centrality:.4f}")

print("\nЦентральность по близости (closeness):")
for user, centrality in sorted_centrality(closeness):
    name = user_names.get(str(user), f"User ID: {user}")
    print(f"{name}, Closeness: {centrality:.4f}")

print("\nСобственная центральность (eigenvector):")
for user, centrality in sorted_centrality(eigenvector):
    name = user_names.get(str(user), f"User ID: {user}")
    print(f"{name}, Eigenvector: {centrality:.4f}")
# Out:
# Имена пользователей успешно сохранены в 'user_names.json'
#
# Центральность по посредничеству (betweenness):
# Даниил Белов, Betweenness: 0.0553
# Александр Краснов, Betweenness: 0.0386
# Владислав Утц, Betweenness: 0.0362
# Екатерина Беликова, Betweenness: 0.0276
# Никита Гусев, Betweenness: 0.0207
# Денис Яценко, Betweenness: 0.0174
# Кирилл Кузьмин, Betweenness: 0.0171
# Danil Egorkin, Betweenness: 0.0152
# Маргарита Моругова, Betweenness: 0.0138
# Никита Цыганков, Betweenness: 0.0129
# Виктория Мезенцева, Betweenness: 0.0099
# Мария Денисова, Betweenness: 0.0080
# Даниил Алабужев, Betweenness: 0.0078
# Nikonov Ivan, Betweenness: 0.0075
# Рахман Кичибеков, Betweenness: 0.0060
# Мария Чиркова, Betweenness: 0.0055
# Влад Лавренов, Betweenness: 0.0053
# Максим Поздняков, Betweenness: 0.0049
# Аня Хоборова, Betweenness: 0.0034
# Вася Елизаветов, Betweenness: 0.0032
# Татьяна Латынова, Betweenness: 0.0030
# ආර්ටියෝම් ඉස්මයිලොව්, Betweenness: 0.0023
# Антон Филиппов, Betweenness: 0.0017
# Человек Без-Имени, Betweenness: 0.0016
# Дима Балабанов, Betweenness: 0.0016
# Alexandr Chekunkov, Betweenness: 0.0007
# Иван Чураков, Betweenness: 0.0004
# Али Zammam, Betweenness: 0.0000
# Ибрахим Хашим-Киджей, Betweenness: 0.0000
# Абдувохид Джумаев, Betweenness: 0.0000
#
# Центральность по близости (closeness):
# Даниил Белов, Closeness: 0.3859
# Александр Краснов, Closeness: 0.3705
# Кирилл Кузьмин, Closeness: 0.3631
# Владислав Утц, Closeness: 0.3572
# Екатерина Беликова, Closeness: 0.3532
# Влад Лавренов, Closeness: 0.3508
# Маргарита Моругова, Closeness: 0.3466
# Никита Гусев, Closeness: 0.3420
# Татьяна Латынова, Closeness: 0.3396
# Виктория Мезенцева, Closeness: 0.3390
# Аня Хоборова, Closeness: 0.3380
# Антон Филиппов, Closeness: 0.3331
# Вася Елизаветов, Closeness: 0.3254
# Максим Поздняков, Closeness: 0.3214
# Рахман Кичибеков, Closeness: 0.3198
# ආර්ටියෝම් ඉස්මයිලොව්, Closeness: 0.3154
# Alexandr Chekunkov, Closeness: 0.3154
# Nikonov Ivan, Closeness: 0.3147
# Иван Чураков, Closeness: 0.3128
# Денис Яценко, Closeness: 0.3090
# Мария Чиркова, Closeness: 0.3084
# Danil Egorkin, Closeness: 0.2979
# Даниил Алабужев, Closeness: 0.2951
# Мария Денисова, Closeness: 0.2918
# Никита Цыганков, Closeness: 0.2850
# Ибрахим Хашим-Киджей, Closeness: 0.2677
# Дима Балабанов, Closeness: 0.2649
# Человек Без-Имени, Closeness: 0.2576
# Али Zammam, Closeness: 0.1937
# Абдувохид Джумаев, Closeness: 0.0008
#
# Собственная центральность (eigenvector):
# Даниил Белов, Eigenvector: 0.1725
# Александр Краснов, Eigenvector: 0.1041
# Кирилл Кузьмин, Eigenvector: 0.0967
# Владислав Утц, Eigenvector: 0.0817
# Виктория Мезенцева, Eigenvector: 0.0682
# Аня Хоборова, Eigenvector: 0.0649
# Влад Лавренов, Eigenvector: 0.0595
# Татьяна Латынова, Eigenvector: 0.0497
# Екатерина Беликова, Eigenvector: 0.0456
# Антон Филиппов, Eigenvector: 0.0435
# Вася Елизаветов, Eigenvector: 0.0298
# Рахман Кичибеков, Eigenvector: 0.0282
# Иван Чураков, Eigenvector: 0.0258
# Маргарита Моругова, Eigenvector: 0.0240
# Максим Поздняков, Eigenvector: 0.0203
# ආර්ටියෝම් ඉස්මයිලොව්, Eigenvector: 0.0199
# Nikonov Ivan, Eigenvector: 0.0189
# Никита Гусев, Eigenvector: 0.0188
# Alexandr Chekunkov, Eigenvector: 0.0160
# Денис Яценко, Eigenvector: 0.0098
# Мария Денисова, Eigenvector: 0.0052
# Danil Egorkin, Eigenvector: 0.0046
# Даниил Алабужев, Eigenvector: 0.0042
# Мария Чиркова, Eigenvector: 0.0029
# Ибрахим Хашим-Киджей, Eigenvector: 0.0026
# Никита Цыганков, Eigenvector: 0.0017
# Дима Балабанов, Eigenvector: 0.0016
# Человек Без-Имени, Eigenvector: 0.0003
# Али Zammam, Eigenvector: 0.0000
# Абдувохид Джумаев, Eigenvector: 0.0000
